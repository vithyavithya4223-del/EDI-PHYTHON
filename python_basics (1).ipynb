# %%
a=5
b=5.2
c='A'
d="Name"
e=True

# %%
print("Integer:",a);
print("Float:",b);
print("Charecter:",c);
print("String:",d);
print("Boolean:",e);
# Out:
# Integer: 5
# Float: 5.2
# Charecter: A
# String: Name
# Boolean: True

# %%
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'bool'>

# %%
 a=15
 b=10
 add=a+b
 print("Add",add)
 sub=a-b
 print("Sub",sub)
 mul=a*b
 print("Mul",mul)
 div=a/b
 print("divide",div)
 mod=a%b
 print("Mod",mod)
 flo_div=a//b
 print("Div",flo_div)
# Out:
# Add 25
# Sub 5
# Mul 150
# divide 1.5
# Mod 5
# Div 1

# %%
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
print(a==b)
print(a!=b)
# Out:
# True
# False
# True
# False
# False
# True

# %%
c=True
d=False

# %%
print(c and d)
print(c or d)
print(not a)
# Out:
# False
# True
# False
